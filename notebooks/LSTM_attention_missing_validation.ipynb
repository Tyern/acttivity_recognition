# %%
import torch
from torch import nn
from torchinfo import summary

from sklearn import tree
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import pytorch_lightning as pl
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import numpy  as np

import json
import os
import glob
import pickle
from itertools import combinations

import warnings
warnings.filterwarnings("ignore")

# %%
DATA_ROOT = "../data/compgan_dataset/"

train_data_file_name_ = "train_data{}.npy"
train_label_file_name_ = "train_label{}.npy"
test_data_file_name_ = "test_data{}.npy"
test_label_file_name_ = "test_label{}.npy"

TRAIN_FOLDER_PATH = os.path.join(DATA_ROOT, "train")
TEST_FOLDER_PATH = os.path.join(DATA_ROOT, "test")
RESULT_FOLDER_PATH = os.path.join(DATA_ROOT, "results")

assert os.path.isdir(TRAIN_FOLDER_PATH) and os.path.isdir(TEST_FOLDER_PATH)
os.makedirs(RESULT_FOLDER_PATH, exist_ok=True)

data_files = sorted(glob.glob(os.path.join(TRAIN_FOLDER_PATH, train_data_file_name_.format("*"))))
print(data_files)
print(len(data_files))
# Out:
# ['../data/compgan_dataset/train/train_data0.npy', '../data/compgan_dataset/train/train_data1.npy', '../data/compgan_dataset/train/train_data10.npy', '../data/compgan_dataset/train/train_data11.npy', '../data/compgan_dataset/train/train_data12.npy', '../data/compgan_dataset/train/train_data13.npy', '../data/compgan_dataset/train/train_data14.npy', '../data/compgan_dataset/train/train_data15.npy', '../data/compgan_dataset/train/train_data2.npy', '../data/compgan_dataset/train/train_data3.npy', '../data/compgan_dataset/train/train_data4.npy', '../data/compgan_dataset/train/train_data5.npy', '../data/compgan_dataset/train/train_data6.npy', '../data/compgan_dataset/train/train_data7.npy', '../data/compgan_dataset/train/train_data8.npy', '../data/compgan_dataset/train/train_data9.npy']
# 16

# %%
# important

label_list = ['歩行(平地)',
 '歩行(階段)',
 'ベッド上での起き上がり',
 'ベッド椅子間の乗り移り(立つ)',
 'ベッド椅子間の乗り移り(立たない)',
 '立ち座り',
 '座位保持・座位バランス',
 '立位保持・立位バランス',
 '関節可動域増大訓練(肩)',
 '関節可動域増大訓練(股関節)']

label_dict = dict(enumerate(label_list))

# %%
# important
eng_label_dict = dict(zip(
    label_list,
    ['Walking', 'Upstair', 'Bed_Standup', 'Change_Bed', 'Change_Bed_Standup', 'Sit_Down', 'Sit', 'Stand', 'Shoulder_Exercise', 'Hip_Exercise']
))

eng_label_list = [eng_label_dict[i] for i in label_list]

# %%
test_user = 0

# %%
def load_train_test(test_user):
    train_data_file_name = train_data_file_name_.format(test_user)
    train_label_file_name = train_label_file_name_.format(test_user)
    test_data_file_name = test_data_file_name_.format(test_user)
    test_label_file_name = test_label_file_name_.format(test_user)

    train_data_file_path = os.path.join(TRAIN_FOLDER_PATH, train_data_file_name)
    train_label_file_path = os.path.join(TRAIN_FOLDER_PATH, train_label_file_name)
    test_data_file_path = os.path.join(TEST_FOLDER_PATH, test_data_file_name)
    test_label_file_path = os.path.join(TEST_FOLDER_PATH, test_label_file_name)

    train_data, train_label = np.load(train_data_file_path), np.load(train_label_file_path)
    test_data, test_label = np.load(test_data_file_path), np.load(test_label_file_path)

    return train_data, train_label, test_data, test_label

# %%
# test
train_data, train_label, test_data, test_label = load_train_test(test_user)

# %%
print(train_data.shape)
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)
# Out:
# (6361, 7, 6, 256)
# (6361,)
# (214, 7, 6, 256)
# (214,)

# %%
# test
l, s, d, w = train_data.shape
train_data = train_data.reshape(l, s * d, w)
train_data = train_data.transpose(0,2,1)

train_data.shape
# Out:
# (6361, 256, 42)

# %%
feature_num = s * d

# %%
class CustomDataset(Dataset):
    def __init__(self, feature_data, label_data, missing_sensor_id_list=None):
        l, s, d, w = feature_data.shape
        self.features = feature_data.reshape(l, s * d, w).transpose(0,2,1)
        self.label = label_data
        
        if missing_sensor_id_list is not None:
            for missing_sensor_id in missing_sensor_id_list:
                self.features[:, :, missing_sensor_id*6:(missing_sensor_id+1)*6] = 0
        
        assert len(self.features) == len(self.label), "features len is not equal to label len"
        
    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, idx):
        x = self.features[idx]
        label = self.label[idx]
        return x, int(label)

# %%
# test
train_data, train_label, test_data, test_label = load_train_test(test_user)
dataset = CustomDataset(
    train_data,
    train_label,
    missing_sensor_id_list=[0]
)

# %%
dataset[0]
# Out:
# (array([[0.        , 0.        , 0.        , ..., 0.5687546 , 0.56854683,
#          0.5687847 ],
#         [0.        , 0.        , 0.        , ..., 0.56876063, 0.5685619 ,
#          0.5688209 ],
#         [0.        , 0.        , 0.        , ..., 0.5689263 , 0.5685017 ,
#          0.5688751 ],
#         ...,
#         [0.        , 0.        , 0.        , ..., 0.5690076 , 0.5688359 ,
#          0.56889015],
#         [0.        , 0.        , 0.        , ..., 0.5688962 , 0.568851  ,
#          0.56892323],
#         [0.        , 0.        , 0.        , ..., 0.5690889 , 0.5687968 ,
#          0.56886303]], dtype=float32),
#  0)

# %%
# test
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# %%
# test
train_dataloader = DataLoader(
    train_dataset, 
    batch_size=8,
    num_workers=0, # number of subprocesses to use for data loading
    shuffle=True)

val_dataloader = DataLoader(
    train_dataset, 
    batch_size=8,
    num_workers=0, # number of subprocesses to use for data loading
    shuffle=False)

# %%
next(train_dataloader.__iter__())[0].shape
# Out:
# torch.Size([8, 256, 42])

# %% [markdown]
# ## model definition

# %%
class SelfAttention(nn.Module):
    def __init__(self, input_dim):
        super(SelfAttention, self).__init__()
        self.input_dim = input_dim
        self.query = nn.Linear(input_dim, input_dim)
        self.key = nn.Linear(input_dim, input_dim)
        self.value = nn.Linear(input_dim, input_dim)
        self.softmax = nn.Softmax(dim=2)
        
    def forward(self, x):
        queries = self.query(x)
        keys = self.key(x)
        values = self.value(x)
        scores = torch.bmm(queries, keys.transpose(1, 2)) / (self.input_dim ** 0.5)
        attention = self.softmax(scores)
        weighted = torch.bmm(attention, values)
        return weighted

# %%
class LSTMModel(pl.LightningModule):
    def __init__(self, hidden_size=128, input_size=30, output_size=6):
        super().__init__()
        self.save_hyperparameters()
        self.example_input_array = torch.Tensor(1024, 200, input_size)
        
        self.rnn1 = nn.LSTM(input_size=input_size, 
                          hidden_size=hidden_size,
                          num_layers=1,
                          batch_first=True)
        
        self.attention1 = SelfAttention(
            input_dim=hidden_size)

        self.rnn2 = nn.LSTM(input_size=hidden_size, 
                          hidden_size=hidden_size,
                          num_layers=1,
                          batch_first=True)
        
        self.attention2 = SelfAttention(
            input_dim=hidden_size
        )
        
        self.seq_1 = nn.Sequential(
            nn.Linear(in_features=hidden_size, out_features=hidden_size),
            nn.BatchNorm1d(num_features=hidden_size),
            nn.Dropout1d(p=0.2),
            nn.ReLU(),
            nn.Linear(in_features=hidden_size, out_features=hidden_size),
            nn.BatchNorm1d(num_features=hidden_size),
            nn.Dropout1d(p=0.2),
            nn.ReLU(),
        )
        
        self.seq_2 = nn.Sequential(
            nn.Linear(in_features=hidden_size, out_features=hidden_size),
            nn.BatchNorm1d(num_features=hidden_size),
            nn.Dropout1d(p=0.2),
            nn.ReLU(),
            nn.Linear(in_features=hidden_size, out_features=hidden_size),
            nn.BatchNorm1d(num_features=hidden_size),
            nn.Dropout1d(p=0.2),
            nn.ReLU(),
        )
        
        self.classifier = nn.Linear(in_features=3 * hidden_size, out_features=output_size)
        
        self.all_test = []
        self.all_pred = []
        
    def forward(self, x):
        activation, _ = self.rnn1(x)
        activation = self.attention1(activation)
        activation, _ = self.rnn2(activation)
        activation = self.attention2(activation)

        b, _, _ = activation.size()
        
        lstm_output = activation[:,-1,:].view(b,-1)
        
        seq_1_output = self.seq_1(lstm_output)
        seq_2_output = self.seq_2(lstm_output)
        
        output = torch.concat([lstm_output, seq_1_output, seq_2_output], dim=1)
        output = self.classifier(output)
        
        return output
    
    def configure_optimizers(self):
        optimizer = torch.optim.Adam(params=self.parameters(), lr=0.0005)
        return optimizer
    
    def training_step(self, batch, batch_idx):
        X, y = batch
        X = X.float()
        # 1. Forward pass
        y_pred = self.forward(X)
        # 2. Calculate  and accumulate loss
        loss = F.cross_entropy(y_pred, y)
        
        self.log("train_loss", loss, prog_bar=True)
        
        return loss
    
    def test_step(self, batch, batch_idx):
        # this is the test loop
        X, y = batch
        X = X.float()
        y = y
    
        # 1. Forward pass
        test_pred_logits = self.forward(X)

        # Calculate and accumulate accuracy
        test_pred_labels = test_pred_logits.argmax(dim=1)
        test_acc = ((test_pred_labels == y).sum().item()/len(test_pred_labels))
        self.log("test_acc", test_acc)
        
        self.all_pred = test_pred_labels
        self.all_test = y
        
    def validation_step(self, batch, batch_idx):
        # this is the validation loop
        X, y = batch
        X = X.float()
        y = y
        
        y_pred = self.forward(X)
        # 2. Calculate  and accumulate loss
        loss = F.cross_entropy(y_pred, y)
        
        self.log("val_loss", loss, prog_bar=True)

# %%
model = LSTMModel()
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# LSTMModel                                --
# ├─LSTM: 1-1                              81,920
# ├─SelfAttention: 1-2                     --
# │    └─Linear: 2-1                       16,512
# │    └─Linear: 2-2                       16,512
# │    └─Linear: 2-3                       16,512
# │    └─Softmax: 2-4                      --
# ├─LSTM: 1-3                              132,096
# ├─SelfAttention: 1-4                     --
# │    └─Linear: 2-5                       16,512
# │    └─Linear: 2-6                       16,512
# │    └─Linear: 2-7                       16,512
# │    └─Softmax: 2-8                      --
# ├─Sequential: 1-5                        --
# │    └─Linear: 2-9                       16,512
# │    └─BatchNorm1d: 2-10                 256
# │    └─Dropout1d: 2-11                   --
# │    └─ReLU: 2-12                        --
# │    └─Linear: 2-13                      16,512
# │    └─BatchNorm1d: 2-14                 256
# │    └─Dropout1d: 2-15                   --
# │    └─ReLU: 2-16                        --
# ├─Sequential: 1-6                        --
# │    └─Linear: 2-17                      16,512
# │    └─BatchNorm1d: 2-18                 256
# │    └─Dropout1d: 2-19                   --
# │    └─ReLU: 2-20                        --
# │    └─Linear: 2-21                      16,512
# │    └─BatchNorm1d: 2-22                 256
# │    └─Dropout1d: 2-23                   --
# │    └─ReLU: 2-24                        --
# ├─Linear: 1-7                            2,310
# =================================================================
# Total params: 382,470
# Trainable params: 382,470
# Non-trainable params: 0
# =================================================================

# %%
list(combinations(range(7),1))
# Out:
# [(0,), (1,), (2,), (3,), (4,), (5,), (6,)]

# %%
from tqdm.auto import tqdm
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger

batch_size = 1024
patience = 20
# missing_sensor_numbers = 0
all_test_pred = {}

for missing_sensor_numbers in range(6):
    print(f"start learning missing_sensor_numbers = {missing_sensor_numbers}")
    
    for missing_index in combinations(range(7),missing_sensor_numbers):
    
        all_test = []
        all_pred = []
    
        # kfold_train_test_index_list = [kfold_train_test_index_list[0]]
    
        for i in range(len(data_files)):
            print(f"\n*************training on User{i}*************")
            train_data, train_label, test_data, test_label = load_train_test(i) # test user
            dataset = CustomDataset(
                train_data,
                train_label,
                missing_sensor_id_list=missing_index,
            )
    
            train_size = int(0.8 * len(dataset))
            val_size = len(dataset) - train_size
    
            train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
            test_dataset =  CustomDataset(
                test_data,
                test_label,
                missing_sensor_id_list=missing_index,
            )
    
            train_dataloader = DataLoader(
                train_dataset, 
                batch_size=batch_size,
                num_workers=4, # number of subprocesses to use for data loading
                shuffle=True)
    
            val_dataloader = DataLoader(
                val_dataset, 
                batch_size=batch_size,
                num_workers=2, # number of subprocesses to use for data loading
                shuffle=False)
    
            test_dataloader = DataLoader(
                test_dataset,
                batch_size=batch_size,
                num_workers=2, # number of subprocesses to use for data loading
                shuffle=False)
    
            model = LSTMModel(hidden_size=128, input_size=feature_num, output_size=len(label_list))
    
            tb_logger = TensorBoardLogger(".")
    
            trainer = pl.Trainer(
                logger=tb_logger,
                callbacks=[EarlyStopping(monitor="val_loss", patience=patience, mode="min")],
            )
            trainer.fit(model, train_dataloader, val_dataloader)
            trainer.test(model, test_dataloader)
    
            all_test.extend(model.all_test)
            all_pred.extend(model.all_pred)
            
        all_test_pred[missing_index] = (all_test, all_pred)
    
    os.makedirs(RESULT_FOLDER_PATH, exist_ok=True)
    with open(os.path.join(RESULT_FOLDER_PATH, f"all_test_pred_{missing_sensor_numbers}.pkl"), "wb") as f:
        pickle.dump(all_test_pred, f)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name       | Type          | Params | In sizes         | Out sizes
# -----------------------------------------------------------------------------------------------------------------------
# 0 | rnn1       | LSTM          | 88.1 K | [1024, 200, 42]  | [[1024, 200, 128], [[1, 1024, 128], [1, 1024, 128]]]
# 1 | attention1 | SelfAttention | 49.5 K | [1024, 200, 128] | [1024, 200, 128]
# 2 | rnn2       | LSTM          | 132 K  | [1024, 200, 128] | [[1024, 200, 128], [[1, 1024, 128], [1, 1024, 128]]]
# 3 | attention2 | SelfAttention | 49.5 K | [1024, 200, 128] | [1024, 200, 128]
# 4 | seq_1      | Sequential    | 33.5 K | [1024, 128]      | [1024, 128]
# 5 | seq_2      | Sequential    | 33.5 K | [1024, 128]      | [1024, 128]
# 6 | classifier | Linear        | 3.9 K  | [1024, 384]      | [1024, 10]
# -----------------------------------------------------------------------------------------------------------------------
# 390 K     Trainable params
# 0         Non-trainable params
# 390 K     Total params
# 1.561     Total estimated model params size (MB)
# start learning missing_sensor_numbers = 0
#
# *************training on User0*************
# Epoch 0: 100%|█████████████████████████████████████| 5/5 [00:01<00:00,  4.21it/s, v_num=659, train_loss=2.160]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 226.85it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.44it/s]
# Epoch 1: 100%|█████████████████████| 5/5 [00:01<00:00,  4.03it/s, v_num=659, train_loss=1.950, val_loss=2.290]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 189.14it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.23it/s]
# Epoch 2: 100%|█████████████████████| 5/5 [00:01<00:00,  3.96it/s, v_num=659, train_loss=1.810, val_loss=2.280]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 224.09it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.38it/s]
# Epoch 3: 100%|█████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=659, train_loss=1.660, val_loss=2.270]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 212.06it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.32it/s]
# Epoch 4: 100%|█████████████████████| 5/5 [00:01<00:00,  4.01it/s, v_num=659, train_loss=1.540, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 226.67it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.39it/s]
# Epoch 5: 100%|█████████████████████| 5/5 [00:01<00:00,  3.96it/s, v_num=659, train_loss=1.440, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.80it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.39it/s]
# Epoch 6: 100%|█████████████████████| 5/5 [00:01<00:00,  3.94it/s, v_num=659, train_loss=1.340, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 199.60it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.28it/s]
# Epoch 7: 100%|█████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=659, train_loss=1.230, val_loss=2.250]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 198.55it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.28it/s]
# Epoch 8: 100%|█████████████████████| 5/5 [00:01<00:00,  3.95it/s, v_num=659, train_loss=1.220, val_loss=2.250]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 194.35it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.03it/s]
# Epoch 9: 100%|█████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=659, train_loss=1.160, val_loss=2.240]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 211.95it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.26it/s]
# Epoch 10: 100%|████████████████████| 5/5 [00:01<00:00,  4.06it/s, v_num=659, train_loss=1.150, val_loss=2.230]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 196.28it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.20it/s]
# Epoch 11: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=659, train_loss=1.120, val_loss=2.220]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 226.78it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.29it/s]
# Epoch 12: 100%|████████████████████| 5/5 [00:01<00:00,  4.00it/s, v_num=659, train_loss=1.030, val_loss=2.220]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 221.22it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.28it/s]
# Epoch 13: 100%|████████████████████| 5/5 [00:01<00:00,  4.00it/s, v_num=659, train_loss=0.996, val_loss=2.230]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 224.74it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.33it/s]
# Epoch 14: 100%|████████████████████| 5/5 [00:01<00:00,  4.02it/s, v_num=659, train_loss=0.981, val_loss=2.240]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 221.89it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.28it/s]
# Epoch 15: 100%|████████████████████| 5/5 [00:01<00:00,  3.91it/s, v_num=659, train_loss=0.922, val_loss=2.200]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.22it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.34it/s]
# Epoch 16: 100%|████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=659, train_loss=0.889, val_loss=2.350]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 217.46it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.24it/s]
# Epoch 17: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=659, train_loss=0.864, val_loss=2.160]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 226.23it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.30it/s]
# Epoch 18: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=659, train_loss=0.941, val_loss=1.890]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 213.67it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.23it/s]
# Epoch 19: 100%|████████████████████| 5/5 [00:01<00:00,  3.94it/s, v_num=659, train_loss=0.866, val_loss=1.760]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 205.56it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.18it/s]
# Epoch 20: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=659, train_loss=0.834, val_loss=1.800]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 191.78it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.00it/s]
# Epoch 21: 100%|████████████████████| 5/5 [00:01<00:00,  3.96it/s, v_num=659, train_loss=0.814, val_loss=2.220]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 193.97it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.08it/s]
# Epoch 22: 100%|████████████████████| 5/5 [00:01<00:00,  4.01it/s, v_num=659, train_loss=0.812, val_loss=2.680]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 195.35it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.11it/s]
# Epoch 23: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=659, train_loss=0.737, val_loss=1.850]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 213.57it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.25it/s]
# Epoch 24: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=659, train_loss=0.776, val_loss=1.850]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 222.39it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.30it/s]
# Epoch 25: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=659, train_loss=0.757, val_loss=2.340]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 234.88it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.31it/s]
# Epoch 26: 100%|████████████████████| 5/5 [00:01<00:00,  4.02it/s, v_num=659, train_loss=0.682, val_loss=2.730]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 205.10it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.16it/s]
# Epoch 27: 100%|████████████████████| 5/5 [00:01<00:00,  3.95it/s, v_num=659, train_loss=0.693, val_loss=3.580]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 212.49it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.21it/s]
# Epoch 28: 100%|████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=659, train_loss=0.651, val_loss=3.010]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 222.16it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.24it/s]
# Epoch 29: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=659, train_loss=0.685, val_loss=2.490]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 219.84it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.27it/s]
# Epoch 30: 100%|████████████████████| 5/5 [00:01<00:00,  3.92it/s, v_num=659, train_loss=0.642, val_loss=2.830]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 221.17it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.04it/s]
# Epoch 31: 100%|████████████████████| 5/5 [00:01<00:00,  3.91it/s, v_num=659, train_loss=0.591, val_loss=3.730]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 221.57it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.20it/s]
# Epoch 32: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=659, train_loss=0.635, val_loss=4.200]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 215.39it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.12it/s]
# Epoch 33: 100%|████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=659, train_loss=0.656, val_loss=4.200]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 230.01it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.17it/s]
# Epoch 34: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=659, train_loss=0.615, val_loss=5.490]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 194.10it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.98it/s]
# Epoch 35: 100%|████████████████████| 5/5 [00:01<00:00,  3.91it/s, v_num=659, train_loss=0.619, val_loss=2.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 190.55it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.91it/s]
# Epoch 36: 100%|████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=659, train_loss=0.602, val_loss=2.620]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 216.91it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.15it/s]
# Epoch 37: 100%|████████████████████| 5/5 [00:01<00:00,  3.94it/s, v_num=659, train_loss=0.586, val_loss=3.190]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 209.42it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.11it/s]
# Epoch 38: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=659, train_loss=0.603, val_loss=3.880]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 222.85it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.18it/s]
# Epoch 38: 100%|████████████████████| 5/5 [00:01<00:00,  3.33it/s, v_num=659, train_loss=0.603, val_loss=3.590]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|█████████████████████████████████████████████████████| 1/1 [00:00<00:00, 41.53it/s]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name       | Type          | Params | In sizes         | Out sizes
# -----------------------------------------------------------------------------------------------------------------------
# 0 | rnn1       | LSTM          | 88.1 K | [1024, 200, 42]  | [[1024, 200, 128], [[1, 1024, 128], [1, 1024, 128]]]
# 1 | attention1 | SelfAttention | 49.5 K | [1024, 200, 128] | [1024, 200, 128]
# 2 | rnn2       | LSTM          | 132 K  | [1024, 200, 128] | [[1024, 200, 128], [[1, 1024, 128], [1, 1024, 128]]]
# 3 | attention2 | SelfAttention | 49.5 K | [1024, 200, 128] | [1024, 200, 128]
# 4 | seq_1      | Sequential    | 33.5 K | [1024, 128]      | [1024, 128]
# 5 | seq_2      | Sequential    | 33.5 K | [1024, 128]      | [1024, 128]
# 6 | classifier | Linear        | 3.9 K  | [1024, 384]      | [1024, 10]
# -----------------------------------------------------------------------------------------------------------------------
# 390 K     Trainable params
# 0         Non-trainable params
# 390 K     Total params
# 1.561     Total estimated model params size (MB)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.4953271150588989
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# *************training on User1*************
# Epoch 0: 100%|█████████████████████████████████████| 5/5 [00:01<00:00,  4.21it/s, v_num=660, train_loss=2.180]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 228.12it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.20it/s]
# Epoch 1: 100%|█████████████████████| 5/5 [00:01<00:00,  4.04it/s, v_num=660, train_loss=1.980, val_loss=2.300]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 212.97it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.12it/s]
# Epoch 2: 100%|█████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=660, train_loss=1.830, val_loss=2.290]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 230.08it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.21it/s]
# Epoch 3: 100%|█████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=660, train_loss=1.690, val_loss=2.280]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 221.03it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.19it/s]
# Epoch 4: 100%|█████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=660, train_loss=1.550, val_loss=2.270]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 222.25it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.78it/s]
# Epoch 5: 100%|█████████████████████| 5/5 [00:01<00:00,  4.00it/s, v_num=660, train_loss=1.450, val_loss=2.270]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 229.57it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.24it/s]
# Epoch 6: 100%|█████████████████████| 5/5 [00:01<00:00,  4.03it/s, v_num=660, train_loss=1.380, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 220.38it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.14it/s]
# Epoch 7: 100%|█████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=660, train_loss=1.300, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.01it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.23it/s]
# Epoch 8: 100%|█████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=660, train_loss=1.260, val_loss=2.250]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 230.48it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.23it/s]
# Epoch 9: 100%|█████████████████████| 5/5 [00:01<00:00,  4.01it/s, v_num=660, train_loss=1.200, val_loss=2.250]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 225.04it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.19it/s]
# Epoch 10: 100%|████████████████████| 5/5 [00:01<00:00,  4.05it/s, v_num=660, train_loss=1.100, val_loss=2.240]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 221.60it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.18it/s]
# Epoch 11: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=660, train_loss=1.050, val_loss=2.230]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.31it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.18it/s]
# Epoch 12: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=660, train_loss=0.990, val_loss=2.220]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 207.35it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.04it/s]
# Epoch 13: 100%|████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=660, train_loss=1.020, val_loss=2.190]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 218.41it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.14it/s]
# Epoch 14: 100%|████████████████████| 5/5 [00:01<00:00,  4.02it/s, v_num=660, train_loss=0.959, val_loss=2.160]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 226.32it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.20it/s]
# Epoch 15: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=660, train_loss=0.952, val_loss=2.130]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 223.60it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.19it/s]
# Epoch 16: 100%|████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=660, train_loss=0.852, val_loss=2.050]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.83it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.20it/s]
# Epoch 17: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=660, train_loss=0.829, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 223.45it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.23it/s]
# Epoch 18: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=660, train_loss=0.841, val_loss=2.420]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 197.09it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.13it/s]
# Epoch 19: 100%|████████████████████| 5/5 [00:01<00:00,  4.03it/s, v_num=660, train_loss=0.801, val_loss=2.660]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 193.17it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.93it/s]
# Epoch 20: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=660, train_loss=0.736, val_loss=2.520]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.08it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.20it/s]
# Epoch 21: 100%|████████████████████| 5/5 [00:01<00:00,  4.00it/s, v_num=660, train_loss=0.775, val_loss=2.370]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 191.01it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.98it/s]
# Epoch 22: 100%|████████████████████| 5/5 [00:01<00:00,  4.06it/s, v_num=660, train_loss=0.747, val_loss=2.530]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 168.09it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.95it/s]
# Epoch 23: 100%|████████████████████| 5/5 [00:01<00:00,  4.04it/s, v_num=660, train_loss=0.671, val_loss=3.340]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 224.21it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.18it/s]
# Epoch 24: 100%|████████████████████| 5/5 [00:01<00:00,  3.98it/s, v_num=660, train_loss=0.710, val_loss=3.650]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 212.77it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.07it/s]
# Epoch 25: 100%|████████████████████| 5/5 [00:01<00:00,  3.89it/s, v_num=660, train_loss=0.707, val_loss=3.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 229.80it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.24it/s]
# Epoch 26: 100%|████████████████████| 5/5 [00:01<00:00,  4.03it/s, v_num=660, train_loss=0.703, val_loss=4.150]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 225.71it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.22it/s]
# Epoch 27: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=660, train_loss=0.693, val_loss=3.430]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 230.47it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.25it/s]
# Epoch 28: 100%|████████████████████| 5/5 [00:01<00:00,  4.02it/s, v_num=660, train_loss=0.598, val_loss=3.770]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 190.49it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 23.97it/s]
# Epoch 29: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=660, train_loss=0.651, val_loss=2.830]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 213.18it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.15it/s]
# Epoch 30: 100%|████████████████████| 5/5 [00:01<00:00,  4.02it/s, v_num=660, train_loss=0.633, val_loss=4.780]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 204.96it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.05it/s]
# Epoch 31: 100%|████████████████████| 5/5 [00:01<00:00,  3.97it/s, v_num=660, train_loss=0.618, val_loss=5.600]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 219.55it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.17it/s]
# Epoch 32: 100%|████████████████████| 5/5 [00:01<00:00,  4.04it/s, v_num=660, train_loss=0.609, val_loss=2.990]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 220.44it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.18it/s]
# Epoch 33: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=660, train_loss=0.565, val_loss=2.570]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 221.62it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.19it/s]
# Epoch 34: 100%|████████████████████| 5/5 [00:01<00:00,  3.99it/s, v_num=660, train_loss=0.596, val_loss=2.450]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.05it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.17it/s]
# Epoch 35: 100%|████████████████████| 5/5 [00:01<00:00,  3.96it/s, v_num=660, train_loss=0.551, val_loss=2.140]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 224.31it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.11it/s]
# Epoch 35: 100%|████████████████████| 5/5 [00:01<00:00,  3.31it/s, v_num=660, train_loss=0.551, val_loss=2.730]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...
#
# *************training on User4*************
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name       | Type          | Params | In sizes         | Out sizes
# -----------------------------------------------------------------------------------------------------------------------
# 0 | rnn1       | LSTM          | 88.1 K | [1024, 200, 42]  | [[1024, 200, 128], [[1, 1024, 128], [1, 1024, 128]]]
# 1 | attention1 | SelfAttention | 49.5 K | [1024, 200, 128] | [1024, 200, 128]
# 2 | rnn2       | LSTM          | 132 K  | [1024, 200, 128] | [[1024, 200, 128], [[1, 1024, 128], [1, 1024, 128]]]
# 3 | attention2 | SelfAttention | 49.5 K | [1024, 200, 128] | [1024, 200, 128]
# 4 | seq_1      | Sequential    | 33.5 K | [1024, 128]      | [1024, 128]
# 5 | seq_2      | Sequential    | 33.5 K | [1024, 128]      | [1024, 128]
# 6 | classifier | Linear        | 3.9 K  | [1024, 384]      | [1024, 10]
# -----------------------------------------------------------------------------------------------------------------------
# 390 K     Trainable params
# 0         Non-trainable params
# 390 K     Total params
# 1.561     Total estimated model params size (MB)
# Epoch 0: 100%|█████████████████████████████████████| 5/5 [00:01<00:00,  4.51it/s, v_num=663, train_loss=2.190]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.54it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.28it/s]
# Epoch 1: 100%|█████████████████████| 5/5 [00:01<00:00,  4.36it/s, v_num=663, train_loss=1.990, val_loss=2.290]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 191.87it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.05it/s]
# Epoch 2: 100%|█████████████████████| 5/5 [00:01<00:00,  4.27it/s, v_num=663, train_loss=1.870, val_loss=2.280]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 227.91it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.31it/s]
# Epoch 3: 100%|█████████████████████| 5/5 [00:01<00:00,  4.32it/s, v_num=663, train_loss=1.810, val_loss=2.270]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 212.51it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.17it/s]
# Epoch 4: 100%|█████████████████████| 5/5 [00:01<00:00,  4.26it/s, v_num=663, train_loss=1.730, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 212.68it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.20it/s]
# Epoch 5: 100%|█████████████████████| 5/5 [00:01<00:00,  4.26it/s, v_num=663, train_loss=1.530, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 212.85it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.22it/s]
# Epoch 6: 100%|█████████████████████| 5/5 [00:01<00:00,  4.27it/s, v_num=663, train_loss=1.470, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 215.09it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.21it/s]
# Epoch 7: 100%|█████████████████████| 5/5 [00:01<00:00,  4.28it/s, v_num=663, train_loss=1.500, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 215.17it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.24it/s]
# Epoch 8: 100%|█████████████████████| 5/5 [00:01<00:00,  4.27it/s, v_num=663, train_loss=1.340, val_loss=2.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 185.88it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.05it/s]
# Epoch 9: 100%|█████████████████████| 5/5 [00:01<00:00,  4.29it/s, v_num=663, train_loss=1.240, val_loss=2.250]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 220.35it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.25it/s]
# Epoch 10: 100%|████████████████████| 5/5 [00:01<00:00,  4.28it/s, v_num=663, train_loss=1.190, val_loss=2.240]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 218.23it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.24it/s]
# Epoch 11: 100%|████████████████████| 5/5 [00:01<00:00,  4.31it/s, v_num=663, train_loss=1.160, val_loss=2.230]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 221.90it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.28it/s]
# Epoch 12: 100%|████████████████████| 5/5 [00:01<00:00,  4.26it/s, v_num=663, train_loss=1.110, val_loss=2.190]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 222.92it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.27it/s]
# Epoch 13: 100%|████████████████████| 5/5 [00:01<00:00,  4.33it/s, v_num=663, train_loss=1.150, val_loss=2.160]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 219.83it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.28it/s]
# Epoch 14: 100%|████████████████████| 5/5 [00:01<00:00,  4.28it/s, v_num=663, train_loss=1.100, val_loss=2.130]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 214.33it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.23it/s]
# Epoch 15: 100%|████████████████████| 5/5 [00:01<00:00,  4.21it/s, v_num=663, train_loss=1.010, val_loss=2.070]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 224.61it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.26it/s]
# Epoch 16: 100%|████████████████████| 5/5 [00:01<00:00,  4.29it/s, v_num=663, train_loss=0.973, val_loss=2.040]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 239.35it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.40it/s]
# Epoch 17: 100%|████████████████████| 5/5 [00:01<00:00,  4.31it/s, v_num=663, train_loss=0.955, val_loss=2.030]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                       | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|████████████████████████▌                        | 1/2 [00:00<00:00, 224.63it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████████| 2/2 [00:00<00:00, 24.23it/s]
# Epoch 18:   0%|                            | 0/5 [00:00<?, ?it/s, v_num=663, train_loss=0.955, val_loss=2.030]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fbc655af1f0>
# Traceback (most recent call last):
#   File "/home/tran/miniconda3/envs/compgan/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "/home/tran/miniconda3/envs/compgan/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1442, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/tran/miniconda3/envs/compgan/lib/python3.8/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/tran/miniconda3/envs/compgan/lib/python3.8/multiprocessing/popen_fork.py", line 44, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/tran/miniconda3/envs/compgan/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/home/tran/miniconda3/envs/compgan/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0%|                                                             | 0/1 [00:00<?, ?it/s]
# *************training on User5*************
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name       | Type          | Params | In sizes         | Out sizes
# -----------------------------------------------------------------------------------------------------------------------
# 0 | rnn1       | LSTM          | 88.1 K | [1024, 200, 42]  | [[1024, 200, 128], [[1, 1024, 128], [1, 1024, 128]]]
# 1 | attention1 | SelfAttention | 49.5 K | [1024, 200, 128] | [1024, 200, 128]
# 2 | rnn2       | LSTM          | 132 K  | [1024, 200, 128] | [[1024, 200, 128], [[1, 1024, 128], [1, 1024, 128]]]
# 3 | attention2 | SelfAttention | 49.5 K | [1024, 200, 128] | [1024, 200, 128]
# 4 | seq_1      | Sequential    | 33.5 K | [1024, 128]      | [1024, 128]
# 5 | seq_2      | Sequential    | 33.5 K | [1024, 128]      | [1024, 128]
# 6 | classifier | Linear        | 3.9 K  | [1024, 384]      | [1024, 10]
# -----------------------------------------------------------------------------------------------------------------------
# 390 K     Trainable params
# 0         Non-trainable params
# 390 K     Total params
# 1.561     Total estimated model params size (MB)
# Epoch 0:   0%|                                                                          | 0/5 [00:00<?, ?it/s]
# Exception ignored in: <function _releaseLock at 0x7fbd6ac31f70>
# Traceback (most recent call last):
#   File "/home/tran/miniconda3/envs/compgan/lib/python3.8/logging/__init__.py", line 227, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0%|                                                             | 0/1 [00:00<?, ?it/s]
# *************training on User6*************
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0%|                                                             | 0/1 [00:00<?, ?it/s]
# *************training on User7*************
# KeyboardInterrupt

# %%
for missing_sensor_numbers in range(6):
    with open(os.path.join(RESULT_FOLDER_PATH, f"all_test_pred_{missing_sensor_numbers}.pkl"), "rb") as f:
        all_test_pred = pickle.load(f)

    if all_test_pred == 0:
        missing_index = list(all_test_pred.keys())[0]
        
        all_tall_test, all_pred = all_test_pred[missing_index]
        
        # print("missing index", missing_index)
        all_test_with_label = [label_list[i] for i in all_test]
        all_pred_with_label = [label_list[i] for i in all_pred]
        
        cf = confusion_matrix(all_test_with_label, all_pred_with_label, labels=label_list)
        sns.heatmap(cf, annot=True, xticklabels=eng_label_list, yticklabels=eng_label_list, fmt='g')
    else:
        row_item = 2
        fig, ax = plt.subplots(len(all_test_pred.keys()) // row_item + len(all_test_pred.keys()) % row_item, row_item, figsize=(13,28))
        
        for idx, missing_index in enumerate(all_test_pred.keys()):
            all_test, all_pred = all_test_pred[missing_index]
            
            # print("missing index", missing_index)
            all_test_with_label = [label_list[i] for i in all_test]
            all_pred_with_label = [label_list[i] for i in all_pred]
            
            cf = confusion_matrix(all_test_with_label, all_pred_with_label, labels=label_list)
            sns.heatmap(cf, ax=ax[idx//row_item][idx%row_item], annot=True, xticklabels=eng_label_list, yticklabels=eng_label_list, fmt='g')
            ax[idx//row_item][idx%row_item].set_title(f"missing_index {missing_index} confusion matrix")
            
    plt.savefig(os.path.join(RESULT_FOLDER_PATH, f"all_test_pred_{missing_sensor_numbers}.jpg"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 for missing_sensor_numbers in range(6):
# ----> 2     with open(os.path.join(RESULT_FOLDER_PATH, f"all_test_pred_{missing_sensor_numbers}.pkl"), "rb") as f:
#       3         all_test_pred = pickle.load(f)
#       5     if all_test_pred == 0:
#
# File ~/miniconda3/envs/compgan/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/compgan_dataset/results/all_test_pred_0.pkl'
